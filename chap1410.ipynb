# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('6504.jpg',0)
hist = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
hist,bins = np.histogram(img.ravel(),256,[0,256]); plt.show()

# %%
print(hist)
# Out:
# [    1     2     2     4     7    12    27    38    65    99   133   170
#    233   358   509   647   854  1021  1392  1742  2194  2686  3242  3752
#   4438  4938  5601  6366  7012  7634  8189  8693  9267  9612 10028 10212
#  10437 10766 10780 10935 10955 10703 10734 10687 10160  9963  9667  9036
#   8641  8289  8020  7674  7237  6895  6653  6427  6006  5694  5329  5035
#   4708  4526  4391  4162  4027  3825  3643  3459  3406  3166  3028  3069
#   2800  2838  2583  2499  2474  2321  2344  2301  2224  2301  2187  2204
#   2188  2225  2100  2095  2109  2152  2187  2142  2227  2219  2232  2263
#   2250  2240  2273  2356  2402  2538  2494  2602  2666  2713  2834  2861
#   2915  2866  2741  2718  2672  2622  2535  2470  2423  2292  2270  2252
#   2057  2037  1965  1853  1764  1649  1576  1570  1500  1352  1299  1247
#   1237  1161  1062  1077   995   975   941   935   926  1113  1322  1402
#   1208   962   884   839   756   705   678   611   582   597   507   506
#    476   414   410   343   382   314   332   305   274   288   263   223
#    217   229   207   193   199   180   236   396   828  1646  1928  2846
#   2118  2202  2016  1962  2160  2359  2810  3211  3109  3225  3215  3439
#   3398  2855  2758  2528  2751  2786  2855  2729  2665  3486  5790  5706
#   6734  4965  5230  5529  5689  6995  9575 13243 23539 39558 51671 33328
#  40897 43038 34548 31278 21119 19921 17967 13876 14097  9358  8978  7069
#   5819  5827  4751  3333  1074   510   294   224   177   167    91    89
#     77    58    34    32    24    19     6     1     7     4     3     1
#      1     0     0     0]

# %%
img = cv2.imread('6504.jpg',0)
plt.hist(img.ravel(),256,[0,256]); plt.show()

# %%
plt.hist(img.ravel(),256,[0,256]); plt.show()

# %%
img = cv2.imread('6504.jpg')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
img = cv2.imread('beach-438500_1280.jpg',0)
# create a mask
mask = np.zeros(img.shape[:2], np.uint8)
mask[100:1210, 100:900] = 255
masked_img = cv2.bitwise_and(img,img,mask = mask)
# Calculate histogram with mask and without mask
# Check third argument for mask
hist_full = cv2.calcHist([img],[0],None,[256],[0,256])
hist_mask = cv2.calcHist([img],[0],mask,[256],[0,256])
plt.subplot(221), plt.imshow(img, 'gray')
plt.subplot(222), plt.imshow(mask,'gray')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])
plt.show()

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img2 = cdf[img]

# %%
cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.subplot(211), plt.imshow(img, 'gray')
plt.subplot(212), plt.imshow(mask,'gray')
plt.xlim([0,256])
plt.show()

# %%
cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')

# %%
img2 = cdf[img]
plt.show()

# %%
img = cv2.imread('beach-438500_1280.jpg',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
cv2.imwrite('res.png',res)
# Out:
# True

# %%
plt.imshow(img2, 'gray')
plt.show()
