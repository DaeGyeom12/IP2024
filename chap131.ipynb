# %% [markdown]
# #### Chap 1.3.1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('Everestgray.png')

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('Everestgray.png',img)
# Out:
# True

# %%
img.shape
# Out:
# (194, 259, 3)

# %%
img[100,100,0]=0

# %%
img[100,100]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img[100,100]=[0,0,0]

# %%
img[0:100,0:100,0]=0

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('Everestgray.png',img)
# Out:
# True

# %%
img[600:800,600:1000]=0

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('Everestgray.png',img)
# Out:
# True

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
img.item(10,10,2)
# Out:
# 94

# %%
img.itemset((10,10,2),100)

# %%
img.item(10,10,2)
# Out:
# 100

# %%
ball = img[280:340, 330:390]

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()
